# %% [markdown]
# # Puebas de conexión
#
# Este notebook se utiliza para probar la conexión a los diferentes servicios (Qdrant, OpenAI, etc.) y verificar que las variables de entorno están correctamente configuradas.

# %%
import os
from qdrant_client import QdrantClient

# %% [markdown]
# ## Qdrant

# %%
QDRANT_URL = os.getenv("QDRANT_URL")
QDRANT_API_KEY = os.getenv("QDRANT_API_KEY")

# %%
qdrant_client = QdrantClient(
    url=QDRANT_URL,
    api_key=QDRANT_API_KEY,
)

print(qdrant_client.get_collections())
